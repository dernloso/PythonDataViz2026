# %% [markdown]
# <a href="https://colab.research.google.com/github/dernloso/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ณนัดดา รัตนศรี

# %%
print('673020490-8')
# Out:
# 673020490-8
